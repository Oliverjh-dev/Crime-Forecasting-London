# %% [markdown]
# 1. Purpose
#
# Evaluate model performance through visual diagnostics and error analysis.
#
# 2. Evaluation Visuals
#
# The notebook automatically generates:
#
# Model Comparison
#
# Bar chart of MAE vs RMSE for GLM and MixedLM.
#
# London Total – Actual vs Predicted
#
# Shows performance across the test horizon.
#
# Borough-Level MAE
#
# Highlights which boroughs are easier/harder to predict.
#
# Residual Diagnostics
#
# Histogram of percentage residuals
#
# Residuals vs fitted values (log-scale fitted)
#
# Coefficient Interpretation (Optional)
#
# If the GLM results file exists, produces:
#
# Incidence Rate Ratios (IRR)
#
# Feature importance chart
#
# 3. Insights Section
#
# Markdown includes:
#
# Interpretation of GLM strengths
#
# Why MixedLM underperformed
#
# Impact of IMD score
#
# Forecast limitations

# %%
# %run ../notebook_init.py

from evaluation import run_evaluation
from IPython.display import Image
import pandas as pd
import os

# %%
run_evaluation()

# %%
Image(filename="../dashboards/evaluation/01_model_comparison.png")

# %%
Image(filename="../dashboards/evaluation/02_total_london_actual_vs_pred.png")

# %%
Image(filename="../dashboards/evaluation/03_borough_mae_glm.png")
